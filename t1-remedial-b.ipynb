# %%
import matplotlib.pyplot as plt
print("Setup terminado")
# Out:
# Setup terminado

# %% [markdown]
# 1. # Ejercicio 1:
# La Asociación de Empresas para el Ahorro de la Energía en la Edificación (aeaee) busca fomen-
# tar la cultura del ahorro de energía y desarrollar la comodidad en las edificaciones para reducir
# el consumo de energía eléctrica, gas y otros combustibles. Para ello, mediante un estudio se
# determinaron los factores siguientes que aportan calor a la vivienda.
#
# ![image.png](attachment:58b9282e-5196-4af1-8843-f515c8d09688.png)
#
#
# ¿A qué conclusiones llegas?
# Según el gráfico circular proporcionado, podemos observar que el calor en las viviendas tiene diferentes causas. La principal fuente de calor es la presencia de personas, lo cual representa aproximadamente el 70% del total. Además, las ventanas contribuyen con aproximadamente el 15% del calor en las viviendas. Por otro lado, tanto la azotea, los muros y los focos/electrodomésticos contribuyen cada uno con aproximadamente un 5% al calor en las edificaciones.
#
# Conclusion:
# En base al gráfico circular, se puede concluir que la presencia de personas es la principal fuente de calor en las viviendas, representando el 70% del total. Las ventanas contribuyen con aproximadamente el 15% del calor, mientras que la azotea, los muros y los focos/electrodomésticos contribuyen cada uno con aproximadamente un 5%. Estos resultados resaltan la importancia de considerar la ocupación humana y mejorar la eficiencia energética de las ventanas para optimizar el confort térmico y reducir el consumo de energía en las viviendas.

# %% [markdown]
# # Ejercicio 2:
# Durante la semana de exámenes, los alumnos suelen desvelarse. Se les preguntó cuántas horas
# dormían y éstos son los resultados:
#
# ![image.png](attachment:7309b389-434f-4221-befc-24e7ad65e8e2.png)
#
# **a) ¿Cuántos alumnos contestaron?**
# 25
#
# **b) ¿Cuál es la clase más alta y cuál es la más baja?**
# Clase alta: 3.8
# Clase baja: 7.4
#
# **c) ¿Hacia dónde está la concentración de la distribución? ¿Qué significa esto?**
# En el gráfico, se observa que la mayor cantidad de estudiantes encuestados durmieron alrededor de 7.4 horas durante la semana de exámenes, lo cual representa la clase con mayor frecuencia. Esta clase corresponde al rango de horas de sueño más bajo. En resumen, la mayoría de los alumnos encuestados durmieron entre 2.6 y 3.8 horas durante la semana de exámenes.import matplotlib.pyplot as plt
# print("Setup terminado")

# %% [markdown]
# # Ejercicio 3:
# Se les preguntó a 15 personas cuál es su presentación favorita de una bebida. Las respuestas
# fueron:
# <table>
#   <tr>
#     <td>tetra pak</td>
#     <td>Botella retornable</td>
#     <td>tetra pak</td>
#   </tr>
#   <tr>
#     <td>Lata</td>
#     <td>Botella de plástico</td>
#     <td>Lata</td>
#   </tr>
#   <tr>
#     <td>Lata</td>
#     <td>Lata</td>
#     <td>tetra pak</td>
#   </tr>
#   <tr>
#     <td>Botella de plástico</td>
#     <td>Lata</td>
#     <td>Botella retornable</td>
#   </tr>
#   <tr>
#     <td>Botella retornable</td>
#     <td>tetra pak</td>
#     <td>Botella retornable</td>
#   </tr>
# </table>
#
# **a)** Construye una distribución de frecuencias.
# <table style="width: 40%; text-align: center;">
#     <tr>
#         <th>Presentación</th>
#         <th>F<sub>a</sub></th>
#         <th>F<sub>r</sub></th>
#     </tr>
#     <tr>
#         <td>Lata</td>
#         <td>5</td>
#         <td>33.33%</td>
#     </tr>
#     <tr>
#         <td>Botella de plástico</td>
#         <td>2</td>
#         <td>13.33%</td>
#     </tr>
#     <tr>
#         <td>Botella retornable</td>
#         <td>4</td>
#         <td>26.67%</td>
#     </tr>
#     <tr>
#         <td>tetra pak</td>
#         <td>4</td>
#         <td>26.67%</td>
#     </tr>
#     <tr style="font-weight: 600;">
#         <td>Total</td>
#         <td>15</td>
#         <td>100%</td>
#     </tr>
# </table>
#
# **b)** Traza un diagrama de barras y uno circular. Escribe tus conclusiones.
# *Conclusiones:*
# La botella de plástico es la opción menos preferida, con solo un 13.33% de respuestas a favor. Tanto las botellas retornables como el tetra pak tienen la misma popularidad, con un 26.67% de preferencia cada una entre los encuestados. Sin embargo, la lata es la presentación favorita de bebida para la mayoría de las personas encuestadas, representando un 33.33% de las respuestas. A pesar de que la preferencia se divide entre las botellas retornables y el tetra pak, la lata sigue siendo la opción más popular en esta muestra.

# %%
marcas_clase = ["Tetra pak", "Lata", "Botella de plastico", "Botella retornable"]
valores_ref_eje = list(range(1, len(marcas_clase) + 1))
fa = [5, 2, 4, 4]
fr = [33.33, 13.33, 26.67, 26.67]

colores = ["#9B59B6", "#8E44AD", "#BE90D4", "#C39BD3", "#913D88", "#AF7AC5", "#76448A"]

plt.barh(valores_ref_eje, fa, color=colores[:len(marcas_clase)])
plt.yticks(valores_ref_eje, marcas_clase)
plt.xlabel('Frecuencia absoluta')
plt.ylabel('Marcas de Clase')
plt.title('Gráfico de barras')
plt.show()

# %%
# Validar lista separaciones 
if 'separaciones' in locals() or 'separaciones' in globals():
    if len(separaciones) == 0:
        print("The list exists and is empty.")
        separaciones = [0] * len(fa)
    else:
        print("The list exists and is not empty.")
else:
    print("The list doesn't exist.")
    separaciones = [0] * len(fa)
# Validar lista separaciones

colores = ["#8E44AD", "#9B59B6", "#BE90D4", "#C39BD3"]

plt.figure(figsize=(10, 5))  # (Ancho, alto)

plt.pie(fr,
        explode=separaciones,  # lista 'separaciones' 
        colors=colores,
        pctdistance=.8,
        counterclock=False,
        startangle=90,
        autopct="%0.1f%%",  # punto decimal
        labels=marcas_clase)

plt.show()
# Out:
# The list exists and is not empty.
